# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %%
try:
    import avi
except ImportError as e:
    print('this is a import error',e)
# Out:
# this is a import error No module named 'avi'

# %% [markdown]
# import error are those which is not found in module of python . and this is handled by except block which is explained in above example where as  module not error is the syntax error occurs when it cannot find the at the declaring path or direction

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# look up error are raised when the something are not found in given list or setor dic for example (when not type the correct index location)list out of range ,use mutable parameter in set data type

# %%
      l =[1,3,5,6,8,9,0,4]
#index    0 1 2 3 4 5 6 7

# %%
try:
    l =[1,3,5,6,8,9,0,4]
    l[8]
except Exception as e:
    print(e)
# Out:
# list index out of range

# %%
set ={[5,6,7,8,9,],7}

# %%
try:
    set ={[5,6,7,8,9,],7}
    set[1]
except Exception as e:
    print(e)
# Out:
# unhashable type: 'list'

# %%
dic={'name':'avichal'}

# %%
try:
    dic={'name':'avichal'}
    dic['key1']
except Exception as e:
    print(e)
# Out:
# 'key1'

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %%
#Aritmatic error are the error which ocurs during the numeric calculation
try:
    100/0
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
try :
    7*7/0
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
import inspect

# %%
Q2
# import inspect module
import inspect
  
# our treeClass function
def treeClass(cls, ind = 0):
    
      # print name of the class
    print ('-' * ind, cls.__name__)
      
    # iterating through subclasses
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
        print("Hierarchy for Built-in exceptions is : ")

# %%
inspect.getclasstree(inspect.getmro(BaseException))
# Out:
# [(object, ()), [(BaseException, (object,))]]

# %%
treeClass(BaseException)
# Out:
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# Hierarchy for Built-in exceptions is :
# --------- MultipartConversionError
# Hierarchy for Built-in exceptions is :
# Hierarchy for Built-in exceptions is :
# ------ StopAsyncIteration
# Hierarchy for Built-in exceptions is :
# ------ StopIteration
# Hierarchy for Built-in exceptions is :
# ------ ImportError
# --------- ModuleNotFoundError
# Hierarchy for Built-in exceptions is :
# --------- ZipImportError
# Hierarchy for Built-in exceptions is :
# Hierarchy for Built-in exceptions is :
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# Hierarchy for Built-in exceptions is :
# ------------ ConnectionAbortedError
# Hierarchy for Built-in exceptions is :
# ------------ ConnectionRefusedError
# Hierarchy for Built-in exceptions is :
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# Hierarchy for Built-in exceptions is :
# ...

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %% [markdown]
# 1 use specific exception
# 2 print always proper message
# 3always try to log you error
# 4 document all error
# 5 cleanup allthe resources
